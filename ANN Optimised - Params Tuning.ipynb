# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
X.shape
# Out:
# (10000, 10)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
labelencoder_X_1 = LabelEncoder()

# %%
X[:,1]
# Out:
# array(['France', 'Spain', 'France', ..., 'France', 'Germany', 'France'],
#       dtype=object)

# %%
X[:,1] = labelencoder_X_1.fit_transform(X[:,1])

# %%
X[:,1]
# Out:
# array([0, 2, 0, ..., 0, 1, 0], dtype=object)

# %%
X[:,2] = labelencoder_X_1.fit_transform(X[:,2])

# %%
len(X[0])
# Out:
# 10

# %%
X
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
X[0]
# Out:
# array([619, 0, 0, 42, 2, 0.0, 1, 1, 1, 101348.88], dtype=object)

# %%
onehotencoder = OneHotEncoder(categorical_features=[1])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
X[0]
# Out:
# array([1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 6.1900000e+02,
#        0.0000000e+00, 4.2000000e+01, 2.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0134888e+05])

# %%
len(X[0])
# Out:
# 12

# %%
X = X[:,1:]

# %%
len(X[0])
# Out:
# 11

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X.shape,X_train.shape
# Out:
# ((10000, 11), (8000, 11))

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
X_train[0]
# Out:
# array([-0.5698444 ,  1.74309049,  0.16958176, -1.09168714, -0.46460796,
#         0.00666099, -1.21571749,  0.8095029 ,  0.64259497, -1.03227043,
#         1.10643166])

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
# Out:
# Using Theano backend.

# %%
# Parameter Tuning
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],
              'epochs': [100, 500],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.5511 - accuracy: 0.7958
# Epoch 2/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4349 - accuracy: 0.7971
# Epoch 3/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4299 - accuracy: 0.7971
# Epoch 4/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4269 - accuracy: 0.7971
# Epoch 5/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4240 - accuracy: 0.7971
# Epoch 6/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4214 - accuracy: 0.7971
# Epoch 7/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4190 - accuracy: 0.8065
# Epoch 8/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4172 - accuracy: 0.8231
# Epoch 9/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4162 - accuracy: 0.8231
# Epoch 10/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4152 - accuracy: 0.8263
# Epoch 11/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4143 - accuracy: 0.8288
# Epoch 12/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4135 - accuracy: 0.8297
# Epoch 13/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4127 - accuracy: 0.8292
# Epoch 14/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4119 - accuracy: 0.8299
# Epoch 15/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4117 - accuracy: 0.8315
# Epoch 16/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4106 - accuracy: 0.8317
# Epoch 17/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4105 - accuracy: 0.8328
# Epoch 18/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4099 - accuracy: 0.8322
# Epoch 19/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4097 - accuracy: 0.8322
# Epoch 20/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4088 - accuracy: 0.8347
# Epoch 21/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4088 - accuracy: 0.8329
# Epoch 22/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4083 - accuracy: 0.8326
# Epoch 23/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4079 - accuracy: 0.8339
# Epoch 24/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4075 - accuracy: 0.8336
# Epoch 25/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4073 - accuracy: 0.8336
# Epoch 26/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4066 - accuracy: 0.8336
# Epoch 27/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4063 - accuracy: 0.8347
# Epoch 28/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4060 - accuracy: 0.8354
# Epoch 29/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4056 - accuracy: 0.8343
# Epoch 30/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4053 - accuracy: 0.8351
# Epoch 31/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4053 - accuracy: 0.8336
# Epoch 32/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4051 - accuracy: 0.8350
# Epoch 33/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4046 - accuracy: 0.8347
# Epoch 34/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4044 - accuracy: 0.8351
# Epoch 35/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4043 - accuracy: 0.8346
# Epoch 36/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4041 - accuracy: 0.8350
# Epoch 37/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4038 - accuracy: 0.8342
# Epoch 38/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4040 - accuracy: 0.8353
# Epoch 39/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4035 - accuracy: 0.8361
# Epoch 40/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4035 - accuracy: 0.8335
# Epoch 41/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4031 - accuracy: 0.8349
# Epoch 42/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4033 - accuracy: 0.8338
# Epoch 43/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4034 - accuracy: 0.8346
# Epoch 44/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4030 - accuracy: 0.8354
# Epoch 45/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4033 - accuracy: 0.8350
# Epoch 46/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4028 - accuracy: 0.8357
# Epoch 47/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4030 - accuracy: 0.8336
# Epoch 48/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4028 - accuracy: 0.8340
# Epoch 49/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4026 - accuracy: 0.8344
# Epoch 50/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4025 - accuracy: 0.8346
# Epoch 51/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4025 - accuracy: 0.8347
# Epoch 52/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4023 - accuracy: 0.8343
# Epoch 53/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4024 - accuracy: 0.8346
# Epoch 54/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4023 - accuracy: 0.8343
# Epoch 55/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4019 - accuracy: 0.8349
# Epoch 56/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4023 - accuracy: 0.8340
# Epoch 57/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4021 - accuracy: 0.8351
# Epoch 58/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4019 - accuracy: 0.8346
# Epoch 59/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4023 - accuracy: 0.8339
# Epoch 60/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4021 - accuracy: 0.8347
# Epoch 61/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4022 - accuracy: 0.8353
# Epoch 62/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4019 - accuracy: 0.8356
# Epoch 63/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4019 - accuracy: 0.8332
# Epoch 64/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4018 - accuracy: 0.8342
# Epoch 65/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4017 - accuracy: 0.8347
# Epoch 66/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4018 - accuracy: 0.8349
# Epoch 67/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4014 - accuracy: 0.8342
# Epoch 68/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4019 - accuracy: 0.8349
# Epoch 69/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4018 - accuracy: 0.8354
# Epoch 70/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4016 - accuracy: 0.8338
# Epoch 71/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4018 - accuracy: 0.8354
# Epoch 72/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4015 - accuracy: 0.8347
# Epoch 73/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4017 - accuracy: 0.8346
# Epoch 74/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4016 - accuracy: 0.8346
# Epoch 75/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4016 - accuracy: 0.8342
# Epoch 76/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4018 - accuracy: 0.8339
# Epoch 77/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4019 - accuracy: 0.8350
# Epoch 78/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.4015 - accuracy: 0.8343
# Epoch 79/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4014 - accuracy: 0.8343
# Epoch 80/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4013 - accuracy: 0.8346
# Epoch 81/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4015 - accuracy: 0.8350
# Epoch 82/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4011 - accuracy: 0.8343
# Epoch 83/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4015 - accuracy: 0.8357
# Epoch 84/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4012 - accuracy: 0.8342
# Epoch 85/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4010 - accuracy: 0.8344
# Epoch 86/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4015 - accuracy: 0.8336
# Epoch 87/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4014 - accuracy: 0.8339
# Epoch 88/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4012 - accuracy: 0.8329
# Epoch 89/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4012 - accuracy: 0.8354
# Epoch 90/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4011 - accuracy: 0.8331
# Epoch 91/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4011 - accuracy: 0.8349
# Epoch 92/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4012 - accuracy: 0.8347
# Epoch 93/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4010 - accuracy: 0.8343
# Epoch 94/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4016 - accuracy: 0.8331
# Epoch 95/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4009 - accuracy: 0.8340
# Epoch 96/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4010 - accuracy: 0.8331
# Epoch 97/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4009 - accuracy: 0.8343
# Epoch 98/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4009 - accuracy: 0.8336
# Epoch 99/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4011 - accuracy: 0.8350
# Epoch 100/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4009 - accuracy: 0.8339
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.5754 - accuracy: 0.7954
# Epoch 2/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4381 - accuracy: 0.7967
# Epoch 3/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4309 - accuracy: 0.7967
# Epoch 4/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4282 - accuracy: 0.7967
# Epoch 5/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4265 - accuracy: 0.7967
# Epoch 6/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4247 - accuracy: 0.7967
# Epoch 7/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4228 - accuracy: 0.7967
# Epoch 8/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4204 - accuracy: 0.7971
# Epoch 9/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4188 - accuracy: 0.8185
# Epoch 10/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4172 - accuracy: 0.8225
# Epoch 11/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4159 - accuracy: 0.8228
# Epoch 12/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4145 - accuracy: 0.8272
# Epoch 13/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4140 - accuracy: 0.8279
# Epoch 14/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4130 - accuracy: 0.8301
# Epoch 15/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4121 - accuracy: 0.8303
# Epoch 16/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4114 - accuracy: 0.8318
# Epoch 17/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4105 - accuracy: 0.8333
# Epoch 18/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4099 - accuracy: 0.8325
# Epoch 19/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4091 - accuracy: 0.8324
# Epoch 20/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4087 - accuracy: 0.8328
# Epoch 21/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4079 - accuracy: 0.8331
# Epoch 22/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4073 - accuracy: 0.8335
# Epoch 23/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4068 - accuracy: 0.8332
# Epoch 24/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4062 - accuracy: 0.8335
# Epoch 25/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4057 - accuracy: 0.8338
# Epoch 26/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4057 - accuracy: 0.8357
# Epoch 27/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4048 - accuracy: 0.8329
# Epoch 28/100
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.4047 - accuracy: 0.8357
# Epoch 29/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4044 - accuracy: 0.8351
# Epoch 30/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4040 - accuracy: 0.8346
# Epoch 31/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4038 - accuracy: 0.8347
# Epoch 32/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4035 - accuracy: 0.8343
# Epoch 33/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4034 - accuracy: 0.8356
# Epoch 34/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4034 - accuracy: 0.8351
# Epoch 35/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4028 - accuracy: 0.8346
# Epoch 36/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4029 - accuracy: 0.8347
# Epoch 37/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4025 - accuracy: 0.8360
# Epoch 38/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4026 - accuracy: 0.8349
# Epoch 39/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4022 - accuracy: 0.8351
# Epoch 40/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4020 - accuracy: 0.8358
# Epoch 41/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4019 - accuracy: 0.8353
# Epoch 42/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4020 - accuracy: 0.8354
# Epoch 43/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4017 - accuracy: 0.8356
# Epoch 44/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4014 - accuracy: 0.8354
# Epoch 45/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4016 - accuracy: 0.8358
# Epoch 46/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4014 - accuracy: 0.8368
# Epoch 47/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4014 - accuracy: 0.8349
# Epoch 48/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4013 - accuracy: 0.8350
# Epoch 49/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4009 - accuracy: 0.8351
# Epoch 50/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4010 - accuracy: 0.8356
# Epoch 51/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4013 - accuracy: 0.8357
# Epoch 52/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4008 - accuracy: 0.8371
# Epoch 53/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4007 - accuracy: 0.8353
# Epoch 54/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4007 - accuracy: 0.8357
# Epoch 55/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4006 - accuracy: 0.8351
# Epoch 56/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4007 - accuracy: 0.8356
# Epoch 57/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4005 - accuracy: 0.8350
# Epoch 58/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4005 - accuracy: 0.8358
# Epoch 59/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4003 - accuracy: 0.8375
# Epoch 60/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4003 - accuracy: 0.8350
# Epoch 61/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4001 - accuracy: 0.8363
# Epoch 62/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4005 - accuracy: 0.8354
# Epoch 63/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4003 - accuracy: 0.8354
# Epoch 64/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4000 - accuracy: 0.8351
# Epoch 65/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4002 - accuracy: 0.8358
# Epoch 66/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4002 - accuracy: 0.8356
# Epoch 67/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4001 - accuracy: 0.8360
# Epoch 68/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3997 - accuracy: 0.8354
# Epoch 69/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4000 - accuracy: 0.8354
# Epoch 70/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3999 - accuracy: 0.8356
# Epoch 71/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3998 - accuracy: 0.8346
# Epoch 72/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3999 - accuracy: 0.8369
# Epoch 73/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3998 - accuracy: 0.8344
# Epoch 74/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.3999 - accuracy: 0.8357
# Epoch 75/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3994 - accuracy: 0.8357
# Epoch 76/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.3996 - accuracy: 0.8364
# Epoch 77/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3996 - accuracy: 0.8353
# Epoch 78/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3997 - accuracy: 0.8361
# Epoch 79/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3997 - accuracy: 0.8356
# Epoch 80/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3993 - accuracy: 0.8354
# Epoch 81/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3994 - accuracy: 0.8347
# Epoch 82/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3994 - accuracy: 0.8368
# Epoch 83/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3996 - accuracy: 0.8347
# Epoch 84/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3991 - accuracy: 0.8349
# Epoch 85/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.3994 - accuracy: 0.8351
# Epoch 86/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3991 - accuracy: 0.8363
# Epoch 87/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3993 - accuracy: 0.8367
# Epoch 88/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 89/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3993 - accuracy: 0.8368
# Epoch 90/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3993 - accuracy: 0.8353
# Epoch 91/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 92/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3992 - accuracy: 0.8367
# Epoch 93/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3993 - accuracy: 0.8363
# Epoch 94/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3994 - accuracy: 0.8371
# Epoch 95/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.3991 - accuracy: 0.8357
# Epoch 96/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.3991 - accuracy: 0.8368
# Epoch 97/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 98/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3993 - accuracy: 0.8354
# Epoch 99/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3989 - accuracy: 0.8358
# Epoch 100/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.3989 - accuracy: 0.8367
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.5697 - accuracy: 0.7944
# Epoch 2/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4358 - accuracy: 0.7956
# Epoch 3/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4307 - accuracy: 0.7956
# Epoch 4/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4277 - accuracy: 0.7956
# Epoch 5/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4249 - accuracy: 0.7956
# Epoch 6/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4220 - accuracy: 0.7956
# Epoch 7/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4202 - accuracy: 0.8079
# Epoch 8/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4188 - accuracy: 0.8218
# Epoch 9/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4176 - accuracy: 0.8229
# Epoch 10/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4168 - accuracy: 0.8261
# Epoch 11/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4156 - accuracy: 0.8281
# Epoch 12/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4146 - accuracy: 0.8296
# Epoch 13/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4138 - accuracy: 0.8317
# Epoch 14/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4131 - accuracy: 0.8326
# Epoch 15/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4120 - accuracy: 0.8319
# Epoch 16/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4117 - accuracy: 0.8342
# Epoch 17/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4111 - accuracy: 0.8344
# Epoch 18/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4104 - accuracy: 0.8342
# Epoch 19/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4100 - accuracy: 0.8336
# Epoch 20/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4094 - accuracy: 0.8338
# Epoch 21/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4089 - accuracy: 0.8340
# Epoch 22/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4086 - accuracy: 0.8346
# Epoch 23/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.4084 - accuracy: 0.8338
# Epoch 24/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4076 - accuracy: 0.8340
# Epoch 25/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4074 - accuracy: 0.8350
# Epoch 26/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4071 - accuracy: 0.8339
# Epoch 27/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4070 - accuracy: 0.8340
# Epoch 28/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4064 - accuracy: 0.8344
# Epoch 29/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4062 - accuracy: 0.8340
# Epoch 30/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4062 - accuracy: 0.8357
# Epoch 31/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4054 - accuracy: 0.8347
# Epoch 32/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4057 - accuracy: 0.8342
# Epoch 33/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4051 - accuracy: 0.8346
# Epoch 34/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4047 - accuracy: 0.8346
# Epoch 35/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4049 - accuracy: 0.8356
# Epoch 36/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4047 - accuracy: 0.8342
# Epoch 37/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4045 - accuracy: 0.8351
# Epoch 38/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4044 - accuracy: 0.8350
# Epoch 39/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4037 - accuracy: 0.8342
# Epoch 40/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4039 - accuracy: 0.8347
# Epoch 41/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4038 - accuracy: 0.8344
# Epoch 42/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4037 - accuracy: 0.8344
# Epoch 43/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4035 - accuracy: 0.8351
# Epoch 44/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4035 - accuracy: 0.8343
# Epoch 45/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4034 - accuracy: 0.8351
# Epoch 46/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4036 - accuracy: 0.8344
# Epoch 47/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4031 - accuracy: 0.8344
# Epoch 48/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4033 - accuracy: 0.8346
# Epoch 49/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4029 - accuracy: 0.8346
# Epoch 50/100
# 7200/7200 [==============================] - 0s 21us/step - loss: 0.4026 - accuracy: 0.8343
# Epoch 51/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4027 - accuracy: 0.8346
# Epoch 52/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4025 - accuracy: 0.8347
# Epoch 53/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.4025 - accuracy: 0.8347
# Epoch 54/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4025 - accuracy: 0.8351
# Epoch 55/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4028 - accuracy: 0.8349
# Epoch 56/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4022 - accuracy: 0.8356
# Epoch 57/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4021 - accuracy: 0.8340
# Epoch 58/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4020 - accuracy: 0.8357
# Epoch 59/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4022 - accuracy: 0.8351
# Epoch 60/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4019 - accuracy: 0.8347
# Epoch 61/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4018 - accuracy: 0.8344
# Epoch 62/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4018 - accuracy: 0.8343
# Epoch 63/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4014 - accuracy: 0.8347
# Epoch 64/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4016 - accuracy: 0.8346
# Epoch 65/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4019 - accuracy: 0.8347
# Epoch 66/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4013 - accuracy: 0.8344
# Epoch 67/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4012 - accuracy: 0.8360
# Epoch 68/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4018 - accuracy: 0.8343
# Epoch 69/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4015 - accuracy: 0.8347
# Epoch 70/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4013 - accuracy: 0.8343
# Epoch 71/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4014 - accuracy: 0.8340
# Epoch 72/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4015 - accuracy: 0.8331
# Epoch 73/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4013 - accuracy: 0.8350
# Epoch 74/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4011 - accuracy: 0.8347
# Epoch 75/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4015 - accuracy: 0.8343
# Epoch 76/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4012 - accuracy: 0.8343
# Epoch 77/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4012 - accuracy: 0.8342
# Epoch 78/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4011 - accuracy: 0.8346
# Epoch 79/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4014 - accuracy: 0.8343
# Epoch 80/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4009 - accuracy: 0.8346
# Epoch 81/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4009 - accuracy: 0.8347
# Epoch 82/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4010 - accuracy: 0.8351
# Epoch 83/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4008 - accuracy: 0.8354
# Epoch 84/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4010 - accuracy: 0.8354
# Epoch 85/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4012 - accuracy: 0.8349
# Epoch 86/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4009 - accuracy: 0.8368
# Epoch 87/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4009 - accuracy: 0.8347
# Epoch 88/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4006 - accuracy: 0.8336
# Epoch 89/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4003 - accuracy: 0.8354
# Epoch 90/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4007 - accuracy: 0.8346
# Epoch 91/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4007 - accuracy: 0.8343
# Epoch 92/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4004 - accuracy: 0.8339
# Epoch 93/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4005 - accuracy: 0.8358
# Epoch 94/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4008 - accuracy: 0.8358
# Epoch 95/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4010 - accuracy: 0.8344
# Epoch 96/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4003 - accuracy: 0.8344
# Epoch 97/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4005 - accuracy: 0.8361
# Epoch 98/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4004 - accuracy: 0.8354
# Epoch 99/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4006 - accuracy: 0.8344
# Epoch 100/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4004 - accuracy: 0.8354
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 6)                 72
# _________________________________________________________________
# dense_11 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.5559 - accuracy: 0.7964
# Epoch 2/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4328 - accuracy: 0.7975
# Epoch 3/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4282 - accuracy: 0.7975
# Epoch 4/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4253 - accuracy: 0.7975
# Epoch 5/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4226 - accuracy: 0.7975
# Epoch 6/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4197 - accuracy: 0.7975
# Epoch 7/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4173 - accuracy: 0.8099
# Epoch 8/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4153 - accuracy: 0.8247
# Epoch 9/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4141 - accuracy: 0.8263
# Epoch 10/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4125 - accuracy: 0.8308
# Epoch 11/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4120 - accuracy: 0.8314
# Epoch 12/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4111 - accuracy: 0.8307
# Epoch 13/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4103 - accuracy: 0.8321
# Epoch 14/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4098 - accuracy: 0.8318
# Epoch 15/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4088 - accuracy: 0.8329
# Epoch 16/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4085 - accuracy: 0.8335
# Epoch 17/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4078 - accuracy: 0.8336
# Epoch 18/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4074 - accuracy: 0.8333
# Epoch 19/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4069 - accuracy: 0.8329
# Epoch 20/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4066 - accuracy: 0.8347
# Epoch 21/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4060 - accuracy: 0.8346
# Epoch 22/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4057 - accuracy: 0.8335
# Epoch 23/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4056 - accuracy: 0.8354
# Epoch 24/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4050 - accuracy: 0.8342
# Epoch 25/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4047 - accuracy: 0.8347
# Epoch 26/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4042 - accuracy: 0.8344
# Epoch 27/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4037 - accuracy: 0.8349
# Epoch 28/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4037 - accuracy: 0.8360
# Epoch 29/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4034 - accuracy: 0.8347
# Epoch 30/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4032 - accuracy: 0.8342
# Epoch 31/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4027 - accuracy: 0.8356
# Epoch 32/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4025 - accuracy: 0.8363
# Epoch 33/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4026 - accuracy: 0.8349
# Epoch 34/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4023 - accuracy: 0.8367
# Epoch 35/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4017 - accuracy: 0.8363
# Epoch 36/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4015 - accuracy: 0.8360
# Epoch 37/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4014 - accuracy: 0.8357
# Epoch 38/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4014 - accuracy: 0.8369
# Epoch 39/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4012 - accuracy: 0.8353
# Epoch 40/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4010 - accuracy: 0.8367
# Epoch 41/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4009 - accuracy: 0.8354
# Epoch 42/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4006 - accuracy: 0.8356
# Epoch 43/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4006 - accuracy: 0.8364
# Epoch 44/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4004 - accuracy: 0.8361
# Epoch 45/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4004 - accuracy: 0.8356
# Epoch 46/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4004 - accuracy: 0.8360
# Epoch 47/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4002 - accuracy: 0.8346
# Epoch 48/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3999 - accuracy: 0.8354
# Epoch 49/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3998 - accuracy: 0.8360
# Epoch 50/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3997 - accuracy: 0.8361
# Epoch 51/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3995 - accuracy: 0.8347
# Epoch 52/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.3998 - accuracy: 0.8372
# Epoch 53/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 54/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3995 - accuracy: 0.8376
# Epoch 55/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 56/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3997 - accuracy: 0.8363
# Epoch 57/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3989 - accuracy: 0.8361
# Epoch 58/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3992 - accuracy: 0.8371
# Epoch 59/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.3991 - accuracy: 0.8372
# Epoch 60/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3990 - accuracy: 0.8388
# Epoch 61/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3987 - accuracy: 0.8375
# Epoch 62/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3989 - accuracy: 0.8368
# Epoch 63/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3993 - accuracy: 0.8358
# Epoch 64/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3988 - accuracy: 0.8363
# Epoch 65/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3988 - accuracy: 0.8357
# Epoch 66/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3989 - accuracy: 0.8356
# Epoch 67/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3988 - accuracy: 0.8357
# Epoch 68/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3988 - accuracy: 0.8367
# Epoch 69/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3986 - accuracy: 0.8357
# Epoch 70/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3986 - accuracy: 0.8354
# Epoch 71/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3992 - accuracy: 0.8365
# Epoch 72/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3985 - accuracy: 0.8354
# Epoch 73/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3982 - accuracy: 0.8358
# Epoch 74/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3984 - accuracy: 0.8358
# Epoch 75/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3981 - accuracy: 0.8354
# Epoch 76/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3983 - accuracy: 0.8347
# Epoch 77/100
# 7200/7200 [==============================] - ETA: 0s - loss: 0.3983 - accuracy: 0.83 - 0s 14us/step - loss: 0.3982 - accuracy: 0.8353
# Epoch 78/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3981 - accuracy: 0.8340
# Epoch 79/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.3982 - accuracy: 0.8365
# Epoch 80/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3984 - accuracy: 0.8351
# Epoch 81/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.3985 - accuracy: 0.8363
# Epoch 82/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3982 - accuracy: 0.8358
# Epoch 83/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.3981 - accuracy: 0.8350
# Epoch 84/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.3980 - accuracy: 0.8361
# Epoch 85/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.3979 - accuracy: 0.8361
# Epoch 86/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.3977 - accuracy: 0.8364
# Epoch 87/100
# 7200/7200 [==============================] - 0s 20us/step - loss: 0.3980 - accuracy: 0.8342
# Epoch 88/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.3977 - accuracy: 0.8361
# Epoch 89/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3981 - accuracy: 0.8350
# Epoch 90/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3979 - accuracy: 0.8363
# Epoch 91/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3978 - accuracy: 0.8350
# Epoch 92/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.3975 - accuracy: 0.8364
# Epoch 93/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.3979 - accuracy: 0.8358
# Epoch 94/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3980 - accuracy: 0.8347
# Epoch 95/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3976 - accuracy: 0.8353
# Epoch 96/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3978 - accuracy: 0.8339
# Epoch 97/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3976 - accuracy: 0.8351
# Epoch 98/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.3975 - accuracy: 0.8361
# Epoch 99/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3974 - accuracy: 0.8372
# Epoch 100/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3977 - accuracy: 0.8354
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 6)                 72
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.5659 - accuracy: 0.7918
# Epoch 2/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4394 - accuracy: 0.7937
# Epoch 3/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4330 - accuracy: 0.7937
# Epoch 4/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4302 - accuracy: 0.7937
# Epoch 5/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4273 - accuracy: 0.7937
# Epoch 6/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4248 - accuracy: 0.7937
# Epoch 7/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4226 - accuracy: 0.8121
# Epoch 8/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4211 - accuracy: 0.8218
# Epoch 9/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4201 - accuracy: 0.8228
# Epoch 10/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4188 - accuracy: 0.8244
# Epoch 11/100
# 7200/7200 [==============================] - 0s 13us/step - loss: 0.4177 - accuracy: 0.8274
# Epoch 12/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4168 - accuracy: 0.8289
# Epoch 13/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4159 - accuracy: 0.8288
# Epoch 14/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4150 - accuracy: 0.8296
# Epoch 15/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4146 - accuracy: 0.8315
# Epoch 16/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4136 - accuracy: 0.8311
# Epoch 17/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4136 - accuracy: 0.8310
# Epoch 18/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4126 - accuracy: 0.8318
# Epoch 19/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4124 - accuracy: 0.8326
# Epoch 20/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4117 - accuracy: 0.8331
# Epoch 21/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4118 - accuracy: 0.8318
# Epoch 22/100
# ...
# Epoch 97/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3971 - accuracy: 0.8356
# Epoch 98/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.3966 - accuracy: 0.8375
# Epoch 99/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3973 - accuracy: 0.8371
# Epoch 100/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.3971 - accuracy: 0.8356
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 6)                 72
# _________________________________________________________________
# dense_29 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.5742 - accuracy: 0.7935
# Epoch 2/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4379 - accuracy: 0.7961
# Epoch 3/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4324 - accuracy: 0.7961
# Epoch 4/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4305 - accuracy: 0.7961
# Epoch 5/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4284 - accuracy: 0.7961
# Epoch 6/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4263 - accuracy: 0.7961
# Epoch 7/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4245 - accuracy: 0.7961
# Epoch 8/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4222 - accuracy: 0.8003
# Epoch 9/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4208 - accuracy: 0.8176
# Epoch 10/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4198 - accuracy: 0.8215
# Epoch 11/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4184 - accuracy: 0.8221
# Epoch 12/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4174 - accuracy: 0.8246
# Epoch 13/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4169 - accuracy: 0.8253
# Epoch 14/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4160 - accuracy: 0.8269
# Epoch 15/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4156 - accuracy: 0.8267
# Epoch 16/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4149 - accuracy: 0.8290
# Epoch 17/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4143 - accuracy: 0.8301
# Epoch 18/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4138 - accuracy: 0.8303
# Epoch 19/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4134 - accuracy: 0.8314
# Epoch 20/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4120 - accuracy: 0.8293
# Epoch 21/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4119 - accuracy: 0.8314
# Epoch 22/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4116 - accuracy: 0.8326
# Epoch 23/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4115 - accuracy: 0.8317
# Epoch 24/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4108 - accuracy: 0.8321
# Epoch 25/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4105 - accuracy: 0.8331
# Epoch 26/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4100 - accuracy: 0.8336
# Epoch 27/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4095 - accuracy: 0.8335
# Epoch 28/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4094 - accuracy: 0.8343
# Epoch 29/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4090 - accuracy: 0.8343
# Epoch 30/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4086 - accuracy: 0.8333
# Epoch 31/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4085 - accuracy: 0.8332
# Epoch 32/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4080 - accuracy: 0.8338
# Epoch 33/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4079 - accuracy: 0.8339
# Epoch 34/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4076 - accuracy: 0.8339
# Epoch 35/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4074 - accuracy: 0.8336
# Epoch 36/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4072 - accuracy: 0.8344
# Epoch 37/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4071 - accuracy: 0.8339
# Epoch 38/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4066 - accuracy: 0.8338
# Epoch 39/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4069 - accuracy: 0.8332
# Epoch 40/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4065 - accuracy: 0.8349
# Epoch 41/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4064 - accuracy: 0.8332
# Epoch 42/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4063 - accuracy: 0.8342
# Epoch 43/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4060 - accuracy: 0.8343
# Epoch 44/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4056 - accuracy: 0.8331
# Epoch 45/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4057 - accuracy: 0.8346
# Epoch 46/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4055 - accuracy: 0.8339
# Epoch 47/100
# 7200/7200 [==============================] - 0s 18us/step - loss: 0.4053 - accuracy: 0.8339
# Epoch 48/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4053 - accuracy: 0.8336
# Epoch 49/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4054 - accuracy: 0.8329
# Epoch 50/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4050 - accuracy: 0.8349
# Epoch 51/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4051 - accuracy: 0.8325
# Epoch 52/100
# 7200/7200 [==============================] - 0s 14us/step - loss: 0.4048 - accuracy: 0.8336
# Epoch 53/100
# 7200/7200 [==============================] - 0s 19us/step - loss: 0.4052 - accuracy: 0.8346
# Epoch 54/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4046 - accuracy: 0.8340
# Epoch 55/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4048 - accuracy: 0.8336
# Epoch 56/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4045 - accuracy: 0.8349
# Epoch 57/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4045 - accuracy: 0.8340
# Epoch 58/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4041 - accuracy: 0.8356
# Epoch 59/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4041 - accuracy: 0.8342
# Epoch 60/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4044 - accuracy: 0.8332
# Epoch 61/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4043 - accuracy: 0.8332
# Epoch 62/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4040 - accuracy: 0.8339
# Epoch 63/100
# 7200/7200 [==============================] - 0s 17us/step - loss: 0.4039 - accuracy: 0.8339
# Epoch 64/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4038 - accuracy: 0.8332
# Epoch 65/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4039 - accuracy: 0.8333
# Epoch 66/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4039 - accuracy: 0.8332
# Epoch 67/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4035 - accuracy: 0.8351
# Epoch 68/100
# 7200/7200 [==============================] - 0s 15us/step - loss: 0.4036 - accuracy: 0.8339
# Epoch 69/100
# 7200/7200 [==============================] - 0s 16us/step - loss: 0.4035 - accuracy: 0.8338
# Epoch 70/100
#   25/7200 [..............................] - ETA: 0s - loss: 0.2249 - accuracy: 0.9200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-8b4a9a7a19f2> in <module>
#      20                            scoring = 'accuracy',
#      21                            cv = 10)
# ---> 22 grid_search = grid_search.fit(X_train, y_train)
#      23 best_parameters = grid_search.best_params_
#      24 best_accuracy = grid_search.best_score_
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, sample_weight, **kwargs)
#     207         if sample_weight is not None:
#     208             kwargs['sample_weight'] = sample_weight
# --> 209         return super(KerasClassifier, self).fit(x, y, **kwargs)
#     210
#     211     def predict(self, x, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     149         fit_args.update(kwargs)
#     150
# --> 151         history = self.model.fit(x, y, **fit_args)
#     152
#     153         return history
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     199                     batch_logs[l] = o
#     200
# --> 201                 callbacks._call_batch_hook('train', 'end', batch_index, batch_logs)
#     202                 if callbacks.model.stop_training:
#     203                     break
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/callbacks/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#      86         self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#      87
# ---> 88         delta_t_median = np.median(self._delta_ts[hook_name])
#      89         if (self._delta_t_batch > 0. and
#      90            delta_t_median > 0.95 * self._delta_t_batch and
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3500     """
#    3501     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3502                     overwrite_input=overwrite_input)
#    3503     if keepdims:
#    3504         return r.reshape(k)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3408         keepdim = (1,) * a.ndim
#    3409
# -> 3410     r = func(a, **kwargs)
#    3411     return r, keepdim
#    3412
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3522         kth = [(sz - 1) // 2]
#    3523     # Check if the array contains any nan's
# -> 3524     if np.issubdtype(a.dtype, np.inexact):
#    3525         kth.append(-1)
#    3526
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     391     """
#     392     if not issubclass_(arg1, generic):
# --> 393         arg1 = dtype(arg1).type
#     394     if not issubclass_(arg2, generic):
#     395         arg2_orig = arg2
#
# KeyboardInterrupt:
